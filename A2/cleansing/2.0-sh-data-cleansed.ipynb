# %%
# import libraries
import numpy as np
import os
import pandas as pd
from sklearn import preprocessing

# %%
# environment settings
os.chdir("../data")
train_data = 'A2trainData_MMAI.xlsx'
test_data = 'A2testData_MMAI.xlsx'

# %%
# read in the train data
df_train = pd.read_excel(train_data)
df_test = pd.read_excel(test_data)

# %%
# get the shape of the train data
df_train.shape
# Out:
# (94859, 17)

# %%
# get the shape of the test data
df_test.shape
# Out:
# (26841, 17)

# %%
# get the head of the train data
df_train.head()
# Out:
#    Year       EPS  Liquidity  Profitability  Productivity  Leverage Ratio  \
# 0  1993 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 1  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 2  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 3  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
# 4  1994 -1.451187  -0.089361        0.05609      0.029753        1.839102
#
#    Market Book Ratio  Tobin's Q   b_umd  Excess Return from Risk Model  \
# 0         120.487587   1.097465 -0.2185                       0.063698
# 1         120.487587   1.097465 -0.2014                       0.054996
# 2         120.487587   1.097465 -0.1991                      -0.024033
# 3         120.487587   1.097465 -0.1895                      -0.087586
# 4         120.487587   1.097465 -0.1666                      -0.173001
#
#     b_hml   alpha   b_smb   Returns   b_mkt  Total Volatility  Output Return %
# 0 -0.1232  0.0003  0.3953  0.068493  0.7534          0.084012          -1.9868
# 1 -0.0908  0.0012  0.3554  0.076923  0.7558          0.082222           8.7838
# 2 -0.0852  0.0015  0.3360 -0.029762  0.7544          0.081773           8.1988
# 3 -0.0755  0.0011  0.3332 -0.122699  0.7639          0.082060           8.6207
# 4 -0.0590  0.0006  0.3310 -0.170213  0.7556          0.082041           1.0582

# %%
# get the head of the test data
df_test.head()
# Out:
#    Year       EPS  Liquidity  Profitability  Productivity  Leverage Ratio  \
# 0  2006  1.598766   0.590079       0.346723      0.142845             0.0
# 1  2006  1.598766   0.590079       0.346723      0.142845             0.0
# 2  2006  1.598766   0.590079       0.346723      0.142845             0.0
# 3  2006  1.598766   0.590079       0.346723      0.142845             0.0
# 4  2006  1.598766   0.590079       0.346723      0.142845             0.0
#
#    Market Book Ratio  Tobin's Q   b_umd  Excess Return from Risk Model  \
# 0        5006.695886   4.229103 -0.3193                       0.005935
# 1        5006.695886   4.229103 -0.3089                      -0.099390
# 2        5006.695886   4.229103 -0.3071                      -0.111551
# 3        5006.695886   4.229103 -0.3057                       0.141249
# 4        5006.695886   4.229103 -0.2754                      -0.090889
#
#     b_hml   alpha   b_smb   Returns   b_mkt  Total Volatility  Output Return %
# 0 -0.8873  0.0178  0.4632  0.050355  1.1038          0.144957           1.0490
# 1 -0.8794  0.0179  0.4689 -0.092968  1.1106          0.144735          -1.3064
# 2 -0.8775  0.0177  0.4520 -0.084246  1.1092          0.144655           9.8097
# 3 -0.8602  0.0181  0.4513  0.122290  1.1144          0.144728           7.4158
# 4 -0.8677  0.0182  0.4290 -0.150874  1.1488          0.144549          21.4339

# %%
# get the tail of the train data
df_train.tail()
# Out:
#        Year       EPS  Liquidity  Profitability  Productivity  Leverage Ratio  \
# 94854  1997  0.315879   0.170860       0.172478      0.044050        0.374495
# 94855  1997  0.315879   0.170860       0.172478      0.044050        0.374495
# 94856  1997  0.315879   0.170860       0.172478      0.044050        0.374495
# 94857  1997  0.684509   0.159757       0.190673      0.070478        0.333782
# 94858  1998  0.684509   0.159757       0.190673      0.070478        0.333782
#
#        Market Book Ratio  Tobin's Q   b_umd  Excess Return from Risk Model  \
# 94854           6.741635   0.880102 -0.2605                       0.064525
# 94855           6.741635   0.880102 -0.2600                       0.054335
# 94856           6.741635   0.880102 -0.2552                       0.004285
# 94857           8.188340   0.979088 -0.2673                      -0.083979
# 94858           8.188340   0.979088 -0.3191                      -0.057627
#
#         b_hml   alpha   b_smb   Returns   b_mkt  Total Volatility  \
# 94854  0.8406 -0.0051  1.1468  0.125926  0.5883          0.108429
# 94855  0.8464 -0.0050  1.1452  0.046053  0.5870          0.108449
# 94856  0.8532 -0.0049  1.1499 -0.024906  0.5875          0.108456
# 94857  0.8442 -0.0049  1.1672 -0.078947  0.5882          0.108571
# 94858  0.7698 -0.0055  1.0703 -0.078571  0.6171          0.106873
#
#        Output Return %
# 94854         -16.1290
# 94855           3.9615
# 94856           0.0000
# 94857          -5.6604
# 94858           7.0000

# %%
# get the tail of the test data
df_test.tail()
# Out:
#        Year      EPS  Liquidity  Profitability  Productivity  Leverage Ratio  \
# 26836  2008  0.07405   0.551824        0.17784      0.010773             0.0
# 26837  2008  0.07405   0.551824        0.17784      0.010773             0.0
# 26838  2008  0.07405   0.551824        0.17784      0.010773             0.0
# 26839  2008  0.07405   0.551824        0.17784      0.010773             0.0
# 26840  2008  0.07405   0.551824        0.17784      0.010773             0.0
#
#        Market Book Ratio  Tobin's Q   b_umd  Excess Return from Risk Model  \
# 26836          16.889035    1.00805 -0.5369                      -0.108534
# 26837          16.889035    1.00805 -0.5446                       0.435511
# 26838          16.889035    1.00805 -0.5166                      -0.065904
# 26839          16.889035    1.00805 -0.4954                      -0.118758
# 26840          16.889035    1.00805 -0.4658                      -0.066314
#
#         b_hml   alpha   b_smb   Returns   b_mkt  Total Volatility  \
# 26836 -1.5086  0.0259  1.5719 -0.030527  1.3126          0.222134
# 26837 -1.4368  0.0279  1.5999  0.200382  1.2410          0.222303
# 26838 -1.3529  0.0260  1.6385 -0.317170  1.3566          0.222349
# 26839 -1.3010  0.0233  1.6173 -0.230501  1.4625          0.222484
# 26840 -1.3260  0.0233  1.5900  0.045386  1.4861          0.222482
#
#        Output Return %
# 26836           6.1709
# 26837           1.0432
# 26838           1.9174
# 26839          -5.6440
# 26840           3.2209

# %%
# rename all the columns to be without spaces and camel cases
df_train.columns = ['year', 'eps', 'liquidity', 'profitability', 'productivity', 'leverageRatio', 'marketBookRatio', 'tobinsQ', 'bUmd', 'excessReturnFromRiskModel', 'bHml', 'alpha', 'bSmb', 'returns', 'bMkt', 'totalVolatility', 'outputReturn']
df_test.columns = ['year', 'eps', 'liquidity', 'profitability', 'productivity', 'leverageRatio', 'marketBookRatio', 'tobinsQ', 'bUmd', 'excessReturnFromRiskModel', 'bHml', 'alpha', 'bSmb', 'returns', 'bMkt', 'totalVolatility', 'outputReturn']

# %%
# get all the train data columns
list(df_train.columns)
# Out:
# ['year',
#  'eps',
#  'liquidity',
#  'profitability',
#  'productivity',
#  'leverageRatio',
#  'marketBookRatio',
#  'tobinsQ',
#  'bUmd',
#  'excessReturnFromRiskModel',
#  'bHml',
#  'alpha',
#  'bSmb',
#  'returns',
#  'bMkt',
#  'totalVolatility',
#  'outputReturn']

# %%
# get all the test data columns
list(df_test.columns)
# Out:
# ['year',
#  'eps',
#  'liquidity',
#  'profitability',
#  'productivity',
#  'leverageRatio',
#  'marketBookRatio',
#  'tobinsQ',
#  'bUmd',
#  'excessReturnFromRiskModel',
#  'bHml',
#  'alpha',
#  'bSmb',
#  'returns',
#  'bMkt',
#  'totalVolatility',
#  'outputReturn']

# %%
# get the description of the train data
df_train.describe().transpose()
# Out:
#                              count         mean          std           min  \
# year                       94859.0  1998.491783     4.607276   1989.000000
# eps                        94859.0     1.302542    21.918165  -2005.961353
# liquidity                  94859.0     0.195645     0.205823     -2.314604
# profitability              94859.0     0.275314     0.734245    -41.429463
# productivity               94859.0     0.100757     0.151144     -1.319534
# leverageRatio              94859.0     1.077061    35.615657   -470.178325
# marketBookRatio            94859.0   799.047340  4994.864432 -61482.280405
# tobinsQ                    94859.0     1.813025     1.892319      0.407340
# bUmd                       94859.0    -0.093917     0.252912     -1.671500
# excessReturnFromRiskModel  94859.0     0.002913     0.107143     -0.724585
# bHml                       94859.0     0.244187     0.447290     -2.795900
# alpha                      94859.0     0.002931     0.006202     -0.028700
# bSmb                       94859.0     0.479678     0.606994     -0.979800
# returns                    94859.0     0.013335     0.113598     -0.702934
# bMkt                       94859.0     0.961640     0.298828     -0.254200
# totalVolatility            94859.0     0.104693     0.039717      0.041888
# outputReturn               94859.0     1.389770    11.778750    -75.925900
#
#                                    25%          50%          75%  \
# year                       1995.000000  1999.000000  2003.000000
# eps                           0.509960     1.404610     2.408461
# liquidity                     0.037265     0.168070     0.326155
# profitability                 0.130109     0.296951     0.487101
# productivity                  0.057215     0.091516     0.136319
# leverageRatio                 0.176964     0.529999     0.984877
# marketBookRatio              18.880120    79.637795   324.076938
# tobinsQ                       1.140711     1.394652     1.932979
# bUmd                         -0.232100    -0.085500     0.059600
# excessReturnFromRiskModel    -0.050177    -0.001346     0.049335
# bHml                         -0.035700     0.286600     0.551600
# alpha                        -0.000700     0.002500     0.006000
# bSmb                          0.040250     0.412100     0.846900
# returns                      -0.043532     0.008333     0.062609
# bMkt                          0.755700     0.962300     1.170500
# totalVolatility               0.077781     0.095431     0.122968
# outputReturn                 -4.220100     0.895500     6.232400
#
#                                      max
# year                         2005.000000
# eps                           168.308411
# liquidity                       1.000000
# profitability                   1.717179
# productivity                    5.143878
# leverageRatio                3096.639175
# marketBookRatio            286051.684211
# tobinsQ                        71.221002
# bUmd                            1.406500
# excessReturnFromRiskModel       3.402935
# bHml                            2.016100
# alpha                           0.058300
# bSmb                            4.598900
# returns                         3.659070
# bMkt                            2.120800
# totalVolatility                 0.470094
# outputReturn                 1100.000000

# %%
# get the description of the test data
df_test.describe().transpose()
# Out:
#                              count         mean          std           min  \
# year                       26841.0  2007.028389     0.818207   2006.000000
# eps                        26841.0     2.036682     7.258677    -52.811972
# liquidity                  26841.0     0.226270     0.245906     -7.114394
# profitability              26841.0     0.185524     1.379922    -60.575770
# productivity               26841.0     0.100027     0.283200    -11.158295
# leverageRatio              26841.0     0.773922     6.975451   -291.258065
# marketBookRatio            26841.0  1082.356475  4662.707279 -92267.451887
# tobinsQ                    26841.0     2.033981     2.824445      0.420477
# bUmd                       26841.0    -0.107617     0.269574     -1.586100
# excessReturnFromRiskModel  26841.0     0.002336     0.108168     -0.676081
# bHml                       26841.0     0.418714     0.573948     -2.745900
# alpha                      26841.0     0.004846     0.007421     -0.018000
# bSmb                       26841.0     0.497266     0.600492     -0.974800
# returns                    26841.0    -0.005013     0.120067     -0.731324
# bMkt                       26841.0     0.937439     0.351417     -0.853100
# totalVolatility            26841.0     0.117443     0.054756      0.043985
# outputReturn               26841.0     0.573884    15.336764    -95.268400
#
#                                    25%          50%          75%           max
# year                       2006.000000  2007.000000  2008.000000   2008.000000
# eps                           0.524687     1.507742     2.658995    211.468676
# liquidity                     0.053075     0.195978     0.365877      0.974138
# profitability                 0.119397     0.285125     0.473958      1.798363
# productivity                  0.053804     0.089275     0.141019      5.143878
# leverageRatio                 0.075061     0.386966     0.776460    229.133333
# marketBookRatio              29.010024   113.802534   547.225662  94802.461765
# tobinsQ                       1.234936     1.561878     2.166459     68.342235
# bUmd                         -0.246400    -0.071700     0.060500      1.321100
# excessReturnFromRiskModel    -0.049580     0.001098     0.052170      3.220120
# bHml                          0.173000     0.528800     0.772100      2.138500
# alpha                         0.000300     0.003500     0.007900      0.056000
# bSmb                          0.083900     0.437100     0.814100      4.525400
# returns                      -0.058132     0.000000     0.053674      3.333330
# bMkt                          0.691700     0.923200     1.169500      2.479900
# totalVolatility               0.078283     0.102296     0.142806      0.508176
# outputReturn                 -6.283800     0.288100     6.715600    315.411000

# %%
# check for any null values in train data
df_train.isnull().any()
# Out:
# year                         False
# eps                          False
# liquidity                    False
# profitability                False
# productivity                 False
# leverageRatio                False
# marketBookRatio              False
# tobinsQ                      False
# bUmd                         False
# excessReturnFromRiskModel    False
# bHml                         False
# alpha                        False
# bSmb                         False
# returns                      False
# bMkt                         False
# totalVolatility              False
# outputReturn                 False
# dtype: bool

# %%
# check for any null values in train data
df_test.isnull().any()
# Out:
# year                         False
# eps                          False
# liquidity                    False
# profitability                False
# productivity                 False
# leverageRatio                False
# marketBookRatio              False
# tobinsQ                      False
# bUmd                         False
# excessReturnFromRiskModel    False
# bHml                         False
# alpha                        False
# bSmb                         False
# returns                      False
# bMkt                         False
# totalVolatility              False
# outputReturn                 False
# dtype: bool

# %%
# get list of unique years in the train data
np.unique(df_train['year'])
# Out:
# array([1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005])

# %%
# get list of unique years in the test data
np.unique(df_test['year'])
# Out:
# array([2006, 2007, 2008])

# %%
# get correlation of train data
corr_train = df_train.corr()
corr_train.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col0 {
#             background-color:  #023858;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col1 {
#             background-color:  #f1ebf5;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col2 {
#             background-color:  #e0deed;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col3 {
#             background-color:  #e3e0ee;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col4 {
#             background-color:  #ede8f3;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col5 {
#             background-color:  #faf3f9;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col6 {
#             background-color:  #dddbec;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col7 {
#             background-color:  #e3e0ee;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col8 {
#             background-color:  #eee9f3;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col9 {
#             background-color:  #f7f0f7;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col10 {
#             background-color:  #79abd0;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col11 {
#             background-color:  #9cb9d9;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col12 {
#             background-color:  #f1ebf4;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col13 {
#             background-color:  #fbf4f9;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col14 {
#             background-color:  #ede7f2;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col15 {
#             background-color:  #c1cae2;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row0_col16 {
#             background-color:  #fbf4f9;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col0 {
#             background-color:  #f2ecf5;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col1 {
#             background-color:  #023858;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col2 {
#             background-color:  #e7e3f0;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col3 {
#             background-color:  #81aed2;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col4 {
#             background-color:  #e4e1ef;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col5 {
#             background-color:  #fcf4fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col6 {
#             background-color:  #eae6f1;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col7 {
#             background-color:  #fcf4fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col8 {
#             background-color:  #d6d6e9;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col9 {
#             background-color:  #faf3f9;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col10 {
#             background-color:  #abbfdc;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col11 {
#             background-color:  #afc1dd;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col12 {
#             background-color:  #f0eaf4;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col13 {
#             background-color:  #fdf5fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col14 {
#             background-color:  #dad9ea;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col15 {
#             background-color:  #e4e1ef;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row1_col16 {
#             background-color:  #fff7fb;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col0 {
#             background-color:  #ebe6f2;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col1 {
#             background-color:  #efe9f3;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col2 {
#             background-color:  #023858;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col3 {
#             background-color:  #c5cce3;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col4 {
#             background-color:  #e6e2ef;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col5 {
#             background-color:  #fdf5fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col6 {
#             background-color:  #f5eff6;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col7 {
#             background-color:  #e2dfee;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col8 {
#             background-color:  #e3e0ee;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col9 {
#             background-color:  #faf2f8;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col10 {
#             background-color:  #d2d3e7;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col11 {
#             background-color:  #7eadd1;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col12 {
#             background-color:  #71a8ce;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col13 {
#             background-color:  #fdf5fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col14 {
#             background-color:  #ced0e6;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col15 {
#             background-color:  #79abd0;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row2_col16 {
#             background-color:  #fef6fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col0 {
#             background-color:  #f6eff7;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col1 {
#             background-color:  #9ab8d8;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col2 {
#             background-color:  #d3d4e7;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col3 {
#             background-color:  #023858;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col4 {
#             background-color:  #c0c9e2;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col5 {
#             background-color:  #fef6fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col6 {
#             background-color:  #e7e3f0;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col7 {
#             background-color:  #f1ebf4;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col8 {
#             background-color:  #c6cce3;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col9 {
#             background-color:  #fcf4fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col10 {
#             background-color:  #b1c2de;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col11 {
#             background-color:  #b0c2de;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col12 {
#             background-color:  #fcf4fa;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col13 {
#             background-color:  #fff7fb;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col14 {
#             background-color:  #e6e2ef;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col15 {
#             background-color:  #fff7fb;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row3_col16 {
#             background-color:  #fef6fb;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col0 {
#             background-color:  #f4eef6;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col1 {
#             background-color:  #ede7f2;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col2 {
#             background-color:  #e5e1ef;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col3 {
#             background-color:  #b0c2de;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col4 {
#             background-color:  #023858;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col5 {
#             background-color:  #fef6fb;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col6 {
#             background-color:  #cccfe5;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b03758row4_col7 {
#             background-color:  #0568a3;
#         }    #T_89121720_f8f9_11e8_a895_3440b5b0375

# %%
# get correlation of test data
corr_test = df_test.corr()
corr_test.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col0 {
#             background-color:  #023858;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col1 {
#             background-color:  #f1ebf4;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col2 {
#             background-color:  #e7e3f0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col3 {
#             background-color:  #dbdaeb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col4 {
#             background-color:  #e8e4f0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col5 {
#             background-color:  #f0eaf4;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col6 {
#             background-color:  #dcdaeb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col7 {
#             background-color:  #e6e2ef;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col8 {
#             background-color:  #cdd0e5;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col9 {
#             background-color:  #fdf5fa;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col10 {
#             background-color:  #a9bfdc;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col11 {
#             background-color:  #9ab8d8;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col12 {
#             background-color:  #dcdaeb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col13 {
#             background-color:  #fff7fb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col14 {
#             background-color:  #d2d2e7;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col15 {
#             background-color:  #cacee5;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row0_col16 {
#             background-color:  #ede8f3;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col0 {
#             background-color:  #e7e3f0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col1 {
#             background-color:  #023858;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col2 {
#             background-color:  #eae6f1;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col3 {
#             background-color:  #d1d2e6;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col4 {
#             background-color:  #dddbec;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col5 {
#             background-color:  #f5eff6;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col6 {
#             background-color:  #dbdaeb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col7 {
#             background-color:  #e4e1ef;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col8 {
#             background-color:  #cdd0e5;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col9 {
#             background-color:  #faf3f9;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col10 {
#             background-color:  #97b7d7;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col11 {
#             background-color:  #a7bddb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col12 {
#             background-color:  #f1ebf4;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col13 {
#             background-color:  #e6e2ef;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col14 {
#             background-color:  #d2d2e7;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col15 {
#             background-color:  #e0deed;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row1_col16 {
#             background-color:  #fdf5fa;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col0 {
#             background-color:  #e9e5f1;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col1 {
#             background-color:  #f4eef6;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col2 {
#             background-color:  #023858;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col3 {
#             background-color:  #9ab8d8;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col4 {
#             background-color:  #adc1dd;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col5 {
#             background-color:  #fcf4fa;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col6 {
#             background-color:  #f0eaf4;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col7 {
#             background-color:  #e4e1ef;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col8 {
#             background-color:  #e5e1ef;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col9 {
#             background-color:  #fdf5fa;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col10 {
#             background-color:  #cccfe5;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col11 {
#             background-color:  #65a3cb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col12 {
#             background-color:  #6fa7ce;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col13 {
#             background-color:  #e9e5f1;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col14 {
#             background-color:  #afc1dd;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col15 {
#             background-color:  #6ba5cd;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row2_col16 {
#             background-color:  #fbf4f9;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col0 {
#             background-color:  #e9e5f1;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col1 {
#             background-color:  #e7e3f0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col2 {
#             background-color:  #a9bfdc;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col3 {
#             background-color:  #023858;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col4 {
#             background-color:  #2a88bc;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col5 {
#             background-color:  #fff7fb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col6 {
#             background-color:  #d9d8ea;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col7 {
#             background-color:  #fff7fb;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col8 {
#             background-color:  #b4c4df;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col9 {
#             background-color:  #fbf3f9;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col10 {
#             background-color:  #7eadd1;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col11 {
#             background-color:  #bbc7e0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col12 {
#             background-color:  #fdf5fa;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col13 {
#             background-color:  #e6e2ef;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col14 {
#             background-color:  #d7d6e9;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col15 {
#             background-color:  #f7f0f7;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row3_col16 {
#             background-color:  #fbf3f9;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col0 {
#             background-color:  #e8e4f0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col1 {
#             background-color:  #e7e3f0;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col2 {
#             background-color:  #abbfdc;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col3 {
#             background-color:  #2081b9;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col4 {
#             background-color:  #023858;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col5 {
#             background-color:  #f7f0f7;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col6 {
#             background-color:  #73a9cf;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b03758row4_col7 {
#             background-color:  #3b92c1;
#         }    #T_89364b2c_f8f9_11e8_a895_3440b5b0375

# %%
# use >0.8 cut off for highly correlated features, and drop them (either returns or excessReturnFromRiskModel)
# no highly anti-correlated features, so we leave everything else as is
df_train = df_train.drop('returns', axis=1)
# drop year column
df_train = df_train.drop('year', axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-fe0d7ceb997d> in <module>()
#       1 # use >0.8 cut off for highly correlated features, and drop them (either returns or excessReturnFromRiskModel)
#       2 # no highly anti-correlated features, so we leave everything else as is
# ----> 3 df_train = df_train.drop('returns', axis=1)
#       4 # drop year column
#       5 df_train = df_train.drop('year', axis=1)
#
# /opt/python/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /opt/python/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['returns'] not contained in axis

# %%
# get all the train data columns
list(df_train.columns)
# Out:
# ['eps',
#  'liquidity',
#  'profitability',
#  'productivity',
#  'leverageRatio',
#  'marketBookRatio',
#  'tobinsQ',
#  'bUmd',
#  'excessReturnFromRiskModel',
#  'bHml',
#  'alpha',
#  'bSmb',
#  'bMkt',
#  'totalVolatility',
#  'outputReturn']

# %%
# use >0.8 cut off for highly correlated features, and drop them (either returns or excessReturnFromRiskModel)
# no highly anti-correlated features, so we leave everything else as is
df_test = df_test.drop('returns', axis=1)
# drop year column
df_test = df_test.drop('year', axis=1)

# %%
# get all the test data columns
list(df_test.columns)

# %%
# preprocess the data
scaler = preprocessing.MinMaxScaler()
# scale all the feature columns and disregard the target column using minmax scaler
df_train[df_train.columns] = scaler.fit_transform(df_train[df_train.columns])
df_test[df_test.columns] = scaler.transform(df_test[df_test.columns])

# %%
# get the head after scaling
df_train.head()
# Out:
#         eps  liquidity  profitability  productivity  leverageRatio  \
# 0  0.921923   0.671345       0.961501      0.208758       0.132336
# 1  0.921923   0.671345       0.961501      0.208758       0.132336
# 2  0.921923   0.671345       0.961501      0.208758       0.132336
# 3  0.921923   0.671345       0.961501      0.208758       0.132336
# 4  0.921923   0.671345       0.961501      0.208758       0.132336
#
#    marketBookRatio   tobinsQ      bUmd  excessReturnFromRiskModel      bHml  \
# 0         0.177257  0.009746  0.472060                   0.190982  0.555424
# 1         0.177257  0.009746  0.477615                   0.188874  0.562157
# 2         0.177257  0.009746  0.478363                   0.169727  0.563321
# 3         0.177257  0.009746  0.481481                   0.154330  0.565337
# 4         0.177257  0.009746  0.488921                   0.133636  0.568766
#
#       alpha      bSmb      bMkt  totalVolatility  outputReturn
# 0  0.333333  0.246491  0.424253         0.098373      0.062877
# 1  0.343678  0.239339  0.425263         0.094193      0.072037
# 2  0.347126  0.235861  0.424674         0.093144      0.071539
# 3  0.342529  0.235359  0.428674         0.093815      0.071898
# 4  0.336782  0.234965  0.425179         0.093770      0.065467

# %%
# get the head after scaling
df_test.head()
# Out:
#         eps  liquidity  profitability  productivity  leverageRatio  \
# 0  0.923326   0.876329       0.968237      0.226255        0.13182
# 1  0.923326   0.876329       0.968237      0.226255        0.13182
# 2  0.923326   0.876329       0.968237      0.226255        0.13182
# 3  0.923326   0.876329       0.968237      0.226255        0.13182
# 4  0.923326   0.876329       0.968237      0.226255        0.13182
#
#    marketBookRatio   tobinsQ      bUmd  excessReturnFromRiskModel      bHml  \
# 0         0.191316  0.053969  0.439311                   0.176988  0.396633
# 1         0.191316  0.053969  0.442690                   0.151470  0.398275
# 2         0.191316  0.053969  0.443275                   0.148524  0.398670
# 3         0.191316  0.053969  0.443730                   0.209771  0.402265
# 4         0.191316  0.053969  0.453574                   0.153529  0.400707
#
#       alpha      bSmb      bMkt  totalVolatility  outputReturn
# 0  0.534483  0.258662  0.571789         0.240700      0.065459
# 1  0.535632  0.259684  0.574653         0.240181      0.063456
# 2  0.533333  0.256655  0.574063         0.239994      0.072909
# 3  0.537931  0.256529  0.576253         0.240165      0.070873
# 4  0.539080  0.252532  0.590737         0.239747      0.082794

# %%
# get the tail after scaling
df_train.tail()
# Out:
#             eps  liquidity  profitability  productivity  leverageRatio  \
# 94854  0.922736   0.749853       0.964199      0.210970       0.131925
# 94855  0.922736   0.749853       0.964199      0.210970       0.131925
# 94856  0.922736   0.749853       0.964199      0.210970       0.131925
# 94857  0.922906   0.746503       0.964621      0.215059       0.131914
# 94858  0.922906   0.746503       0.964621      0.215059       0.131914
#
#        marketBookRatio   tobinsQ      bUmd  excessReturnFromRiskModel  \
# 94854         0.176930  0.006676  0.458415                   0.191183
# 94855         0.176930  0.006676  0.458577                   0.188714
# 94856         0.176930  0.006676  0.460136                   0.176588
# 94857         0.176934  0.008074  0.456205                   0.155204
# 94858         0.176934  0.008074  0.439376                   0.161588
#
#            bHml     alpha      bSmb      bMkt  totalVolatility  outputReturn
# 94854  0.755715  0.271264  0.381200  0.354737         0.155395      0.050851
# 94855  0.756920  0.272414  0.380913  0.354189         0.155442      0.067936
# 94856  0.758333  0.273563  0.381756  0.354400         0.155458      0.064567
# 94857  0.756463  0.273563  0.384857  0.354695         0.155726      0.059753
# 94858  0.741002  0.266667  0.367487  0.366863         0.151761      0.070520

# %%
# get the tail after scaling
df_test.tail()
# Out:
#             eps  liquidity  profitability  productivity  leverageRatio  \
# 26836  0.922625   0.864788       0.964323      0.205821        0.13182
# 26837  0.922625   0.864788       0.964323      0.205821        0.13182
# 26838  0.922625   0.864788       0.964323      0.205821        0.13182
# 26839  0.922625   0.864788       0.964323      0.205821        0.13182
# 26840  0.922625   0.864788       0.964323      0.205821        0.13182
#
#        marketBookRatio   tobinsQ      bUmd  excessReturnFromRiskModel  \
# 26836         0.176959  0.008483  0.368616                   0.149255
# 26837         0.176959  0.008483  0.366114                   0.281064
# 26838         0.176959  0.008483  0.375211                   0.159583
# 26839         0.176959  0.008483  0.382099                   0.146777
# 26840         0.176959  0.008483  0.391715                   0.159483
#
#            bHml     alpha      bSmb      bMkt  totalVolatility  outputReturn
# 26836  0.267519  0.627586  0.457400  0.659705         0.420933      0.069815
# 26837  0.282440  0.650575  0.462420  0.629558         0.421328      0.065454
# 26838  0.299875  0.628736  0.469339  0.678232         0.421435      0.066197
# 26839  0.310661  0.597701  0.465539  0.722821         0.421750      0.059767
# 26840  0.305466  0.597701  0.460645  0.732758         0.421746      0.067306

# %%
# describe the scaled data
df_train.describe().transpose()
# Out:
#                              count      mean       std  min       25%  \
# eps                        94859.0  0.923190  0.010081  0.0  0.922825
# liquidity                  94859.0  0.757330  0.062096  0.0  0.709547
# profitability              94859.0  0.966582  0.017017  0.0  0.963217
# productivity               94859.0  0.219743  0.023384  0.0  0.213007
# leverageRatio              94859.0  0.132122  0.009985  0.0  0.131870
# marketBookRatio            94859.0  0.179209  0.014372  0.0  0.176964
# tobinsQ                    94859.0  0.019850  0.026723  0.0  0.010356
# bUmd                       94859.0  0.512535  0.082168  0.0  0.467641
# excessReturnFromRiskModel  94859.0  0.176256  0.025958  0.0  0.163393
# bHml                       94859.0  0.631772  0.092953  0.0  0.573608
# alpha                      94859.0  0.363576  0.071293  0.0  0.321839
# bSmb                       94859.0  0.261616  0.108806  0.0  0.182847
# bMkt                       94859.0  0.511933  0.125822  0.0  0.425221
# totalVolatility            94859.0  0.146671  0.092752  0.0  0.083821
# outputReturn               94859.0  0.065749  0.010017  0.0  0.060978
#
#                                 50%       75%  max
# eps                        0.923237  0.923699  1.0
# liquidity                  0.749011  0.796704  1.0
# profitability              0.967084  0.971491  1.0
# productivity               0.218313  0.225245  1.0
# leverageRatio              0.131969  0.132096  1.0
# marketBookRatio            0.177139  0.177843  1.0
# tobinsQ                    0.013942  0.021544  1.0
# bUmd                       0.515270  0.562411  1.0
# excessReturnFromRiskModel  0.175224  0.187502  1.0
# bHml                       0.640586  0.695657  1.0
# alpha                      0.358621  0.398851  1.0
# bSmb                       0.249503  0.327442  1.0
# bMkt                       0.512211  0.599874  1.0
# totalVolatility            0.125040  0.189348  1.0
# outputReturn               0.065328  0.069867  1.0

# %%
# describe the scaled data
df_test.describe().transpose()
# Out:
#                              count      mean       std       min       25%  \
# eps                        26841.0  0.923528  0.003338  0.898301  0.922832
# liquidity                  26841.0  0.766570  0.074189 -1.448073  0.714317
# profitability              26841.0  0.964501  0.031982 -0.443750  0.962969
# productivity               26841.0  0.219630  0.043816 -1.522224  0.212479
# leverageRatio              26841.0  0.132037  0.001956  0.050162  0.131841
# marketBookRatio            26841.0  0.180025  0.013417 -0.088582  0.176994
# tobinsQ                    26841.0  0.022971  0.039886  0.000186  0.011687
# bUmd                       26841.0  0.508084  0.087581  0.027745  0.462995
# excessReturnFromRiskModel  26841.0  0.176116  0.026207  0.011751  0.163538
# bHml                       26841.0  0.668041  0.119274  0.010391  0.616978
# alpha                      26841.0  0.385581  0.085296  0.122989  0.333333
# bSmb                       26841.0  0.264769  0.107640  0.000896  0.190672
# bMkt                       26841.0  0.501743  0.147965 -0.252168  0.398274
# totalVolatility            26841.0  0.176445  0.127874  0.004897  0.084994
# outputReturn               26841.0  0.065055  0.013042 -0.016449  0.059223
#
#                                 50%       75%       max
# eps                        0.923284  0.923814  1.019850
# liquidity                  0.757430  0.808688  0.992198
# profitability              0.966810  0.971186  1.001882
# productivity               0.217967  0.225973  1.000000
# leverageRatio              0.131929  0.132038  0.196060
# marketBookRatio            0.177238  0.178485  0.449696
# tobinsQ                    0.016304  0.024842  0.959347
# bUmd                       0.519753  0.562703  0.972255
# excessReturnFromRiskModel  0.175816  0.188189  0.955708
# bHml                       0.690919  0.741480  1.025436
# alpha                      0.370115  0.420690  0.973563
# bSmb                       0.253984  0.321562  0.986825
# bMkt                       0.495747  0.599453  1.151200
# totalVolatility            0.141072  0.235676  1.088934
# outputReturn               0.064812  0.070278  0.332790

# %%
# write back the complete dataframe into one csv
df_train.to_csv(os.path.join(cwd, 'data', '2.0-sh-train-data.csv'), index=False)
df_test.to_csv(os.path.join(cwd, 'data', '2.0-sh-test-data.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-bd304c23c0df> in <module>()
#       1 # write back the complete dataframe into one csv
# ----> 2 df_train.to_csv(os.path.join(cwd, 'data', '2.0-sh-train-data.csv'), index=False)
#       3 df_test.to_csv(os.path.join(cwd, 'data', '2.0-sh-test-data.csv'), index=False)
#
# /opt/python/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# /opt/python/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# /opt/python/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: '/global/home/mma_shasan/mmai-823/A2/cleansing/data/2.0-sh-train-data.csv'
