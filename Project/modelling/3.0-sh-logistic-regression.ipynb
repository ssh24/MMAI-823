# %%
# import standard libraries
import numpy as np
import os as os
import pandas as pd
import time

# %%
# import modelling libraries
from sklearn import linear_model, model_selection
import numerox as nx

# %%
# set the data working directory
os.chdir(os.path.join(os.getcwd(), "..", "data"))

# %%
# download the latest numerai dataset
# data = nx.download("numerai_dataset.zip")

# to make it faster use an existing dataset
data = nx.load_zip("numerai_dataset.zip")

# %%
# environment settings
MODEL_NAME = "logistic-regression"
FOLDER_NAME = "submission"

# %%
# extend the logistic model class offered by numerox
class logistic(nx.Model):

    def __init__(self, params):
        self.p = params

    def fit_predict(self, dfit, dpre, tournament):
        model = linear_model.LogisticRegression(C=self.p['C'], 
                                                solver=self.p['solver'], 
                                                multi_class=self.p['multi_class'])
        model.fit(dfit.x, dfit.y[tournament])
        yhat = model.predict_proba(dpre.x)[:, 1]
        return dpre.ids, yhat

# %%
# parameters required for hyper-tuning the model
C = [0.0001, 0.001, 0.01]
solver = ["newton-cg", "lbfgs", "sag", "saga"]
multi_class = ["ovr", "multinomial", "auto"]

# %%
# combination of parameters
parameters = {'C': C,
             'solver': solver,
             'multi_class': multi_class}

# %%
# use grid search cv to find the best parameters
train_data = pd.read_csv(os.path.join(os.getcwd(), "numerai_dataset", "numerai_training_data.csv"), header=0)
X = np.array(train_data.loc[:, :"feature50"])
X.shape
y_train = train_data.iloc[:, train_data.columns == "target_bernie"])
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1072aaa16d56> in <module>()
#       3 X = np.array(train_data.loc[:, :"feature50"])
#       4 X.shape
# ----> 5 y_train = array(train_data.iloc[:, train_data.columns == "target_bernie"])
#       6 y_train
#
# NameError: name 'array' is not defined

# %%
# list of tournaments
tournaments = ["bernie", "elizabeth", "jordan", "ken", "charles", "frank", "hillary"]

# %%
# set the directory to save the submissions
os.chdir(os.path.join(os.getcwd(), "..", "modelling", FOLDER_NAME, MODEL_NAME))

# %%
# define kfold cross validation split
kfold_split = 5

# loop through each tournament and print the input for train and validation
for index in range(0, len(tournaments)):
    # get the tournament name
    tournament = tournaments[index]
    
    print "*********** TOURNAMENT " + tournament + " ***********"
    
    # set the target name for the tournament
    target = "target_" + tournament
    
    # set the y train with the target variable
    y = y_train = train_data.iloc[:, train_data.columns == target].values.reshape(-1,)
    
    # use GroupKFold for splitting the era
    group_kfold = model_selection.GroupKFold(n_splits=kfold_split)
    
    counter = 1
    
    print ">> group eras using kfold split\n"
    
    for train_index, test_index in group_kfold.split(X, y, groups=train_data['era']):
        # X_train takes the 50 features only for training and leave the other columns
        X_train = X[train_index][:,3:]
        # y_train remains the same
        y_train = y[train_index]
        
        print ">> running split #", counter
        
        print ">> finding best params"
        clf = model_selection.GridSearchCV(linear_model.LogisticRegression(), parameters, scoring="neg_log_loss", cv=kfold_split, n_jobs=-1)
        clf.fit(X_train, y_train)
        best_params = clf.best_params_
        print ">> best params: ", best_params

        # create a new logistic regression model for the tournament
        model = logistic(best_params)

        print ">> training info:"
        train = nx.backtest(model, data, tournament, verbosity=1)

        print ">> validation info:"
        validation = nx.production(model, data, tournament, verbosity=1)

        print ">> saving validation info: "
        validation.to_csv(MODEL_NAME + "-" + tournament + "-" + str(counter) + ".csv")
        print ">> done saving validation info"

        print "\n"
        
        counter=counter+1
# Out:
# *********** TOURNAMENT bernie ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692583  0.5187  0.5125  0.0170   tourn    bernie
# std   0.001457  0.0251  0.0193  0.0006  region     train
# min   0.687834  0.4542  0.4699  0.0156    eras       120
# max   0.696270  0.5993  0.5712  0.0191  consis  0.608333
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692469  0.5200  0.5144  0.0171   tourn      bernie
# std   0.001107  0.0184  0.0156  0.0003  region  validation
# min   0.690483  0.4912  0.4875  0.0166    eras          12
# max   0.694352  0.5521  0.5442  0.0174  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.001, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=auto, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692583  0.5187  0.5125  0.0170   tourn    bernie
# std   0.001456  0.0251  0.0193  0.0006  region     train
# min   0.687834  0.4541  0.4697  0.0156    eras       120
# max   0.696271  0.5993  0.5712  0.0191  consis  0.608333
# >> validation info:
# logistic(multi_class=auto, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692466  0.5201  0.5140  0.0171   tourn      bernie
# std   0.001114  0.0185  0.0158  0.0003  region  validation
# min   0.690477  0.4911  0.4860  0.0166    eras          12
# max   0.694372  0.5522  0.5423  0.0174  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# >> best params:  {'multi_class': 'multinomial', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=multinomial, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692599  0.5186  0.5124  0.0188   tourn    bernie
# std   0.001677  0.0260  0.0196  0.0007  region     train
# min   0.687058  0.4469  0.4609  0.0171    eras       120
# max   0.697162  0.6038  0.5740  0.0213  consis  0.616667
# >> validation info:
# logistic(multi_class=multinomial, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692489  0.5197  0.5141  0.0186   tourn      bernie
# std   0.001244  0.0190  0.0167  0.0003  region  validation
# min   0.690233  0.4891  0.4828  0.0181    eras          12
# max   0.694690  0.5533  0.5449  0.0190  consis    0.666667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692583  0.5187  0.5125  0.0170   tourn    bernie
# std   0.001456  0.0251  0.0193  0.0006  region     train
# min   0.687834  0.4541  0.4697  0.0156    eras       120
# max   0.696271  0.5993  0.5712  0.0191  consis  0.608333
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692466  0.5201  0.5140  0.0171   tourn      bernie
# std   0.001114  0.0185  0.0158  0.0003  region  validation
# min   0.690477  0.4911  0.4860  0.0166    eras          12
# max   0.694372  0.5522  0.5423  0.0174  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# /Users/sakib@ibm.com/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692583  0.5187  0.5125  0.0170   tourn    bernie
# std   0.001457  0.0251  0.0193  0.0006  region     train
# min   0.687834  0.4542  0.4699  0.0156    eras       120
# max   0.696270  0.5993  0.5712  0.0191  consis  0.608333
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692469  0.5200  0.5144  0.0171   tourn      bernie
# std   0.001107  0.0184  0.0156  0.0003  region  validation
# min   0.690483  0.4912  0.4875  0.0166    eras          12
# max   0.694352  0.5521  0.5442  0.0174  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# *********** TOURNAMENT elizabeth ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=auto, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692580  0.5184  0.5118  0.0166   tourn  elizabeth
# std   0.001330  0.0233  0.0180  0.0006  region      train
# min   0.689052  0.4567  0.4663  0.0149    eras        120
# max   0.696028  0.5806  0.5586  0.0181  consis   0.608333
# >> validation info:
# logistic(multi_class=auto, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692514  0.5191  0.5125  0.0167   tourn   elizabeth
# std   0.001158  0.0196  0.0172  0.0003  region  validation
# min   0.690569  0.4816  0.4785  0.0162    eras          12
# max   0.694854  0.5524  0.5438  0.0170  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'newton-cg'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=newton-cg)
#        logloss     auc     acc    ystd   stats
# mean  0.692580  0.5184  0.5118  0.0166   tourn  elizabeth
# std   0.001330  0.0233  0.0180  0.0006  region      train
# min   0.689052  0.4567  0.4663  0.0149    eras        120
# max   0.696028  0.5806  0.5586  0.0181  consis   0.608333
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=newton-cg)
#        logloss     auc     acc    ystd   stats
# mean  0.692514  0.5191  0.5125  0.0167   tourn   elizabeth
# std   0.001158  0.0196  0.0171  0.0003  region  validation
# min   0.690569  0.4816  0.4785  0.0162    eras          12
# max   0.694854  0.5524  0.5436  0.0170  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# >> best params:  {'multi_class': 'multinomial', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=multinomial, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692586  0.5184  0.5117  0.0183   tourn  elizabeth
# std   0.001485  0.0236  0.0182  0.0007  region      train
# min   0.688716  0.4504  0.4603  0.0163    eras        120
# max   0.696802  0.5804  0.5606  0.0200  consis        0.6
# >> validation info:
# logistic(multi_class=multinomial, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692514  0.5191  0.5119  0.0182   tourn   elizabeth
# std   0.001270  0.0198  0.0177  0.0003  region  validation
# min   0.690493  0.4798  0.4740  0.0176    eras          12
# max   0.695174  0.5510  0.5408  0.0185  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692580  0.5184  0.5117  0.0166   tourn  elizabeth
# std   0.001331  0.0233  0.0180  0.0006  region      train
# min   0.689048  0.4567  0.4661  0.0149    eras        120
# max   0.696024  0.5806  0.5582  0.0181  consis   0.608333
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692514  0.5191  0.5124  0.0167   tourn   elizabeth
# std   0.001159  0.0196  0.0172  0.0003  region  validation
# min   0.690566  0.4816  0.4783  0.0162    eras          12
# max   0.694859  0.5525  0.5442  0.0170  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692580  0.5184  0.5117  0.0166   tourn  elizabeth
# std   0.001331  0.0233  0.0180  0.0006  region      train
# min   0.689048  0.4567  0.4661  0.0149    eras        120
# max   0.696024  0.5806  0.5582  0.0181  consis   0.608333
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692514  0.5191  0.5124  0.0167   tourn   elizabeth
# std   0.001159  0.0196  0.0172  0.0003  region  validation
# min   0.690566  0.4816  0.4783  0.0162    eras          12
# max   0.694859  0.5525  0.5442  0.0170  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# *********** TOURNAMENT jordan ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692538  0.5194  0.5133  0.0171   tourn    jordan
# std   0.001338  0.0230  0.0176  0.0006  region     train
# min   0.689580  0.4456  0.4607  0.0155    eras       120
# max   0.696778  0.5707  0.5521  0.0187  consis  0.616667
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692500  0.5196  0.5137  0.0172   tourn      jordan
# std   0.000995  0.0173  0.0149  0.0003  region  validation
# min   0.690816  0.4962  0.4903  0.0167    eras          12
# max   0.694011  0.5467  0.5360  0.0175  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692538  0.5194  0.5133  0.0171   tourn    jordan
# std   0.001338  0.0230  0.0176  0.0006  region     train
# min   0.689580  0.4456  0.4607  0.0155    eras       120
# max   0.696778  0.5707  0.5521  0.0187  consis  0.616667
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692500  0.5196  0.5137  0.0172   tourn      jordan
# std   0.000995  0.0173  0.0149  0.0003  region  validation
# min   0.690816  0.4962  0.4903  0.0167    eras          12
# max   0.694011  0.5467  0.5360  0.0175  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# /Users/sakib@ibm.com/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692557  0.5198  0.5134  0.0218   tourn    jordan
# std   0.001972  0.0262  0.0194  0.0009  region     train
# min   0.688777  0.4300  0.4422  0.0196    eras       120
# max   0.699268  0.5711  0.5534  0.0243  consis  0.583333
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692648  0.5179  0.5134  0.0212   tourn      jordan
# std   0.001264  0.0176  0.0143  0.0004  region  validation
# min   0.690445  0.4934  0.4949  0.0205    eras          12
# max   0.694627  0.5468  0.5370  0.0216  consis    0.666667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692557  0.5198  0.5134  0.0218   tourn    jordan
# std   0.001972  0.0262  0.0194  0.0009  region     train
# min   0.688777  0.4300  0.4422  0.0196    eras       120
# max   0.699268  0.5711  0.5534  0.0243  consis  0.583333
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692648  0.5179  0.5134  0.0212   tourn      jordan
# std   0.001264  0.0176  0.0143  0.0004  region  validation
# min   0.690445  0.4934  0.4949  0.0205    eras          12
# max   0.694627  0.5468  0.5370  0.0216  consis    0.666667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692538  0.5194  0.5133  0.0171   tourn    jordan
# std   0.001338  0.0230  0.0176  0.0006  region     train
# min   0.689580  0.4456  0.4607  0.0155    eras       120
# max   0.696778  0.5707  0.5521  0.0187  consis  0.616667
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692500  0.5196  0.5137  0.0172   tourn      jordan
# std   0.000995  0.0173  0.0149  0.0003  region  validation
# min   0.690816  0.4962  0.4903  0.0167    eras          12
# max   0.694011  0.5467  0.5360  0.0175  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# *********** TOURNAMENT ken ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692622  0.5181  0.5117  0.0163   tourn       ken
# std   0.001408  0.0252  0.0195  0.0006  region     train
# min   0.688914  0.4486  0.4644  0.0149    eras       120
# max   0.696421  0.5824  0.5627  0.0181  consis  0.616667
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692365  0.5220  0.5153  0.0164   tourn         ken
# std   0.001024  0.0178  0.0153  0.0003  region  validation
# min   0.690553  0.4927  0.4892  0.0160    eras          12
# max   0.694204  0.5531  0.5417  0.0167  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692622  0.5181  0.5116  0.0163   tourn       ken
# std   0.001408  0.0252  0.0195  0.0006  region     train
# min   0.688917  0.4486  0.4644  0.0150    eras       120
# max   0.696422  0.5824  0.5624  0.0182  consis  0.616667
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692366  0.5220  0.5154  0.0165   tourn         ken
# std   0.001023  0.0178  0.0154  0.0003  region  validation
# min   0.690552  0.4929  0.4890  0.0160    eras          12
# max   0.694198  0.5531  0.5419  0.0167  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=auto, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692622  0.5181  0.5117  0.0163   tourn       ken
# std   0.001408  0.0252  0.0195  0.0006  region     train
# min   0.688914  0.4486  0.4647  0.0149    eras       120
# max   0.696421  0.5824  0.5627  0.0181  consis  0.616667
# >> validation info:
# logistic(multi_class=auto, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692365  0.5220  0.5153  0.0164   tourn         ken
# std   0.001024  0.0178  0.0153  0.0003  region  validation
# min   0.690553  0.4927  0.4890  0.0160    eras          12
# max   0.694204  0.5531  0.5419  0.0167  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.001, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=auto, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692622  0.5181  0.5117  0.0163   tourn       ken
# std   0.001408  0.0252  0.0195  0.0006  region     train
# min   0.688914  0.4486  0.4644  0.0149    eras       120
# max   0.696421  0.5824  0.5627  0.0181  consis  0.616667
# >> validation info:
# logistic(multi_class=auto, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692365  0.5220  0.5153  0.0164   tourn         ken
# std   0.001024  0.0178  0.0153  0.0003  region  validation
# min   0.690553  0.4927  0.4892  0.0160    eras          12
# max   0.694204  0.5531  0.5417  0.0167  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692622  0.5181  0.5117  0.0163   tourn       ken
# std   0.001408  0.0252  0.0195  0.0006  region     train
# min   0.688914  0.4486  0.4647  0.0149    eras       120
# max   0.696421  0.5824  0.5627  0.0181  consis  0.616667
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692365  0.5220  0.5153  0.0164   tourn         ken
# std   0.001024  0.0178  0.0153  0.0003  region  validation
# min   0.690554  0.4927  0.4892  0.0160    eras          12
# max   0.694204  0.5531  0.5417  0.0167  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# *********** TOURNAMENT charles ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692821  0.5144  0.5101  0.0139   tourn  charles
# std   0.001061  0.0218  0.0171  0.0009  region    train
# min   0.690413  0.4597  0.4660  0.0122    eras      120
# max   0.695606  0.5632  0.5509  0.0154  consis    0.625
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692372  0.5233  0.5165  0.0138   tourn     charles
# std   0.000899  0.0186  0.0138  0.0003  region  validation
# min   0.690979  0.4775  0.4858  0.0133    eras          12
# max   0.694656  0.5538  0.5417  0.0142  consis    0.833333
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692821  0.5144  0.5101  0.0139   tourn  charles
# std   0.001061  0.0218  0.0171  0.0009  region    train
# min   0.690413  0.4597  0.4660  0.0122    eras      120
# max   0.695606  0.5632  0.5509  0.0154  consis    0.625
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692372  0.5233  0.5165  0.0138   tourn     charles
# std   0.000899  0.0186  0.0138  0.0003  region  validation
# min   0.690979  0.4775  0.4858  0.0133    eras          12
# max   0.694656  0.5538  0.5417  0.0142  consis    0.833333
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# >> best params:  {'multi_class': 'multinomial', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=multinomial, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692830  0.5144  0.5099  0.0156   tourn   charles
# std   0.001201  0.0221  0.0175  0.0008  region     train
# min   0.690145  0.4611  0.4686  0.0138    eras       120
# max   0.695610  0.5632  0.5529  0.0171  consis  0.616667
# >> validation info:
# logistic(multi_class=multinomial, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692369  0.5226  0.5166  0.0153   tourn     charles
# std   0.000992  0.0185  0.0140  0.0003  region  validation
# min   0.690926  0.4764  0.4860  0.0147    eras          12
# max   0.694922  0.5514  0.5419  0.0157  consis    0.916667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'multinomial', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=multinomial, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692829  0.5145  0.5099  0.0156   tourn   charles
# std   0.001203  0.0221  0.0176  0.0009  region     train
# min   0.690119  0.4617  0.4675  0.0138    eras       120
# max   0.695635  0.5635  0.5535  0.0171  consis  0.616667
# >> validation info:
# logistic(multi_class=multinomial, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692370  0.5226  0.5165  0.0153   tourn     charles
# std   0.000991  0.0185  0.0140  0.0003  region  validation
# min   0.690928  0.4764  0.4860  0.0147    eras          12
# max   0.694922  0.5513  0.5422  0.0157  consis    0.916667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=auto, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692820  0.5144  0.5100  0.0139   tourn   charles
# std   0.001060  0.0218  0.0172  0.0009  region     train
# min   0.690409  0.4599  0.4665  0.0122    eras       120
# max   0.695599  0.5632  0.5509  0.0154  consis  0.616667
# >> validation info:
# logistic(multi_class=auto, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692369  0.5233  0.5165  0.0138   tourn     charles
# std   0.000901  0.0187  0.0138  0.0003  region  validation
# min   0.690973  0.4774  0.4862  0.0133    eras          12
# max   0.694660  0.5538  0.5415  0.0142  consis    0.833333
# >> saving validation info:
# >> done saving validation info
#
#
# *********** TOURNAMENT frank ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'multinomial', 'C': 0.001, 'solver': 'sag'}
# >> training info:
# logistic(multi_class=multinomial, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692274  0.5233  0.5160  0.0205   tourn     frank
# std   0.001799  0.0254  0.0190  0.0007  region     train
# min   0.686193  0.4610  0.4677  0.0184    eras       120
# max   0.697042  0.6076  0.5731  0.0222  consis  0.666667
# >> validation info:
# logistic(multi_class=multinomial, C=0.001, solver=sag)
#        logloss     auc     acc    ystd   stats
# mean  0.692462  0.5203  0.5127  0.0204   tourn       frank
# std   0.001301  0.0183  0.0147  0.0003  region  validation
# min   0.689468  0.4983  0.4937  0.0198    eras          12
# max   0.694004  0.5602  0.5430  0.0208  consis    0.666667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.001, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692306  0.5229  0.5153  0.0186   tourn  frank
# std   0.001587  0.0248  0.0189  0.0006  region  train
# min   0.687027  0.4614  0.4721  0.0167    eras    120
# max   0.696553  0.6039  0.5720  0.0200  consis  0.675
# >> validation info:
# logistic(multi_class=ovr, C=0.001, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692480  0.5200  0.5125  0.0187   tourn       frank
# std   0.001192  0.0182  0.0149  0.0003  region  validation
# min   0.689702  0.4984  0.4953  0.0182    eras          12
# max   0.693893  0.5602  0.5430  0.0191  consis    0.666667
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692260  0.5236  0.5165  0.0233   tourn  frank
# std   0.002143  0.0265  0.0202  0.0008  region  train
# min   0.684667  0.4626  0.4696  0.0208    eras    120
# max   0.697637  0.6161  0.5826  0.0252  consis   0.65
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692485  0.5203  0.5136  0.0227   tourn       frank
# std   0.001435  0.0182  0.0139  0.0003  region  validation
# min   0.689234  0.4981  0.4970  0.0221    eras          12
# max   0.694191  0.5596  0.5411  0.0232  consis    0.583333
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692260  0.5236  0.5165  0.0233   tourn  frank
# std   0.002143  0.0265  0.0202  0.0008  region  train
# min   0.684667  0.4626  0.4696  0.0208    eras    120
# max   0.697637  0.6161  0.5826  0.0252  consis   0.65
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692485  0.5203  0.5136  0.0227   tourn       frank
# std   0.001435  0.0182  0.0139  0.0003  region  validation
# min   0.689234  0.4981  0.4970  0.0221    eras          12
# max   0.694191  0.5596  0.5411  0.0232  consis    0.583333
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# >> best params:  {'multi_class': 'multinomial', 'C': 0.001, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=multinomial, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692274  0.5233  0.5159  0.0205   tourn     frank
# std   0.001799  0.0254  0.0190  0.0007  region     train
# min   0.686193  0.4610  0.4677  0.0184    eras       120
# max   0.697041  0.6076  0.5729  0.0222  consis  0.666667
# >> validation info:
# logistic(multi_class=multinomial, C=0.001, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692462  0.5203  0.5127  0.0204   tourn       frank
# std   0.001301  0.0183  0.0147  0.0003  region  validation
# min   0.689468  0.4983  0.4935  0.0198    eras          12
# max   0.694004  0.5603  0.5430  0.0208  consis    0.666667
# >> saving validation info:
# >> done saving validation info
#
#
# *********** TOURNAMENT hillary ***********
# >> group eras using kfold split
#
# >> running split # 1
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.01, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=auto, C=0.01, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692456  0.5214  0.5157  0.0182   tourn  hillary
# std   0.001230  0.0195  0.0149  0.0010  region    train
# min   0.689836  0.4583  0.4629  0.0161    eras      120
# max   0.696685  0.5635  0.5486  0.0216  consis    0.675
# >> validation info:
# logistic(multi_class=auto, C=0.01, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692564  0.5192  0.5145  0.0178   tourn     hillary
# std   0.000933  0.0153  0.0119  0.0002  region  validation
# min   0.691466  0.4860  0.4892  0.0173    eras          12
# max   0.694617  0.5397  0.5343  0.0181  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 2
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692458  0.5213  0.5157  0.0182   tourn   hillary
# std   0.001226  0.0195  0.0150  0.0010  region     train
# min   0.689889  0.4583  0.4629  0.0161    eras       120
# max   0.696687  0.5628  0.5490  0.0216  consis  0.658333
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692562  0.5192  0.5147  0.0177   tourn     hillary
# std   0.000930  0.0153  0.0118  0.0002  region  validation
# min   0.691459  0.4859  0.4888  0.0173    eras          12
# max   0.694613  0.5399  0.5348  0.0181  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 3
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692456  0.5214  0.5157  0.0182   tourn  hillary
# std   0.001230  0.0195  0.0149  0.0010  region    train
# min   0.689836  0.4583  0.4629  0.0161    eras      120
# max   0.696685  0.5635  0.5486  0.0216  consis    0.675
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692564  0.5192  0.5145  0.0178   tourn     hillary
# std   0.000933  0.0153  0.0118  0.0002  region  validation
# min   0.691466  0.4860  0.4892  0.0173    eras          12
# max   0.694617  0.5397  0.5343  0.0181  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 4
# >> finding best params
# >> best params:  {'multi_class': 'auto', 'C': 0.01, 'solver': 'saga'}
# >> training info:
# logistic(multi_class=auto, C=0.01, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692456  0.5214  0.5157  0.0182   tourn  hillary
# std   0.001230  0.0195  0.0149  0.0010  region    train
# min   0.689836  0.4583  0.4629  0.0161    eras      120
# max   0.696685  0.5635  0.5486  0.0216  consis    0.675
# >> validation info:
# logistic(multi_class=auto, C=0.01, solver=saga)
#        logloss     auc     acc    ystd   stats
# mean  0.692564  0.5192  0.5145  0.0178   tourn     hillary
# std   0.000933  0.0153  0.0119  0.0002  region  validation
# min   0.691466  0.4860  0.4892  0.0173    eras          12
# max   0.694617  0.5397  0.5343  0.0181  consis        0.75
# >> saving validation info:
# >> done saving validation info
#
#
# >> running split # 5
# >> finding best params
# >> best params:  {'multi_class': 'ovr', 'C': 0.01, 'solver': 'lbfgs'}
# >> training info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692458  0.5213  0.5157  0.0182   tourn   hillary
# std   0.001226  0.0195  0.0150  0.0010  region     train
# min   0.689889  0.4583  0.4629  0.0161    eras       120
# max   0.696687  0.5628  0.5490  0.0216  consis  0.658333
# >> validation info:
# logistic(multi_class=ovr, C=0.01, solver=lbfgs)
#        logloss     auc     acc    ystd   stats
# mean  0.692562  0.5192  0.5147  0.0177   tourn     hillary
# std   0.000930  0.0153  0.0118  0.0002  region  validation
# min   0.691459  0.4859  0.4888  0.0173    eras          12
# max   0.694613  0.5399  0.5348  0.0181  consis        0.75
# >> saving validation info:
# >> done saving validation info
